# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import ast

# %%
# %%time
from collections import defaultdict
import spacy
from collections import Counter
nlp = spacy.load('en_core_web_sm')
# Out:
# CPU times: user 506 ms, sys: 56.1 ms, total: 563 ms
# Wall time: 620 ms

# %%
# %%time
from ml_model.boba_business import BobaBusiness
bb = BobaBusiness('vCEc52697fPzYGh_bzS29A')
bb.get_drink_items()[0]
# Out:
# CPU times: user 902 ms, sys: 45.4 ms, total: 948 ms
# Wall time: 1.01 s
# {'drink_name': 'oolong milk tea',
#  'score': 2,
#  'reviews': [{'stars': 3,
#    'text': "Got milk foam oolong with white boba and it was really good! Not too sweet or salty and just enough ice. The second time I had gotten pudding and regular boba with my oolong milk tea, however the pudding looked curdled. I asked someone and they had said that it was good to drink so it may just be the appearance (or a type I'm unaware of). The texture was grainy and not smooth like other puddings I have had, but the taste was sweet. Milk foam was my favorite drink, so I will stick to that! Good overall :)",
#    'date': '2018-12-29 22:06:15.000000',
#    'review_id': '3JTmOuxEJEUWtmUC_wkYYQ'},
#   {'stars': 4,
# ...

# %%
items, reviews = bb.get_keyword_items(['boba'])
reviews['white boba']
# Out:
#    stars                                               text  \
# 0      3  Got milk foam oolong with white boba and it wa...
#
#                          date
# 0  2018-12-29 22:06:15.000000

# %%
bb.noun_counts.most_common()
# Out:
# [('i', 118),
#  ('it', 67),
#  ('boba', 53),
#  ('tea', 39),
#  ('you', 28),
#  ('they', 27),
#  ('me', 25),
#  ('place', 24),
#  ('drink', 17),
#  ('area', 17),
#  ('drinks', 17),
#  ('which', 15),
#  ('we', 11),
#  ('that', 10),
#  ('hill', 10),
#  ('sugar', 8),
#  ('spot', 8),
#  ('flavors', 8),
#  ('boston', 8),
#  ('games', 7),
#  ('texture', 7),
#  ('shop', 7),
#  ('staff', 7),
#  ('what', 6),
#  ('people', 6),
#  ('all', 6),
#  ('cups', 6),
#  ('cup', 6),
#  ('places', 6),
#  ('employees', 6),
#  ('this', 6),
#  ('day', 5),
#  ('who', 5),
#  ('matcha', 5),
#  ('time', 5),
#  ('ice', 5),
#  ('decor', 5),
#  ('milk', 5),
#  ('mi', 5),
#  ('sweetness', 4),
#  ('space', 4),
#  ('jenga', 4),
#  ('bit', 4),
#  ('chewy', 4),
#  ('fries', 4),
#  ('some', 4),
#  ('things', 4),
#  ('menu', 4),
#  ('interior', 4),
#  ('friends', 4),
#  ('them', 4),
#  ('she', 4),
#  ('neighborhood', 4),
#  ('side', 3),
#  ('game', 3),
#  ('price', 3),
#  ('taro', 3),
#  ('those', 3),
#  ('amount', 3),
# ...

# %%
bb.weighted_noun_scores.most_common(20)
# Out:
# [('sandwich', 212314225.05307856),
#  ('boba', 69828722.00263505),
#  ('chewiness', 49019607.84313726),
#  ('mi', 39062500.0),
#  ('chewy', 16393442.622950818),
#  ('jenga', 15209125.47528517),
#  ('ubereats', 13175230.566534914),
#  ('fries', 13029315.960912053),
#  ('lychee', 11235955.056179775),
#  ('matcha', 10683760.683760684),
#  ('shop', 9320905.459387483),
#  ('carrot', 9174311.926605504),
#  ('syrupy', 8547008.547008546),
#  ('meals', 7874015.748031495),
#  ('serve', 7812499.999999999),
#  ('teas', 6293706.293706293),
#  ('allston', 5128205.128205128),
#  ('slush', 4338394.793926247),
#  ('oolong', 4166666.666666667),
#  ('options', 4032258.064516129)]
