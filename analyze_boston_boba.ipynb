# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import ast
import utils
from sqlalchemy import create_engine

# %%
boston_boba = pd.read_csv('data/boston_boba_reviews.csv')

# %%
boston_boba
# Out:
#                   business_id               name             address    city  \
# 0      8xNY-EwTl6j1Wp4XcBZg8Q  Dumpling Daughter        37 Center St  Weston
# 1      8xNY-EwTl6j1Wp4XcBZg8Q  Dumpling Daughter        37 Center St  Weston
# 2      8xNY-EwTl6j1Wp4XcBZg8Q  Dumpling Daughter        37 Center St  Weston
# 3      8xNY-EwTl6j1Wp4XcBZg8Q  Dumpling Daughter        37 Center St  Weston
# 4      8xNY-EwTl6j1Wp4XcBZg8Q  Dumpling Daughter        37 Center St  Weston
# ...                       ...                ...                 ...     ...
# 14103  W_YBG1lPLB-cehQbwtXKow            Chatime  333 Huntington Ave  Boston
# 14104  W_YBG1lPLB-cehQbwtXKow            Chatime  333 Huntington Ave  Boston
# 14105  W_YBG1lPLB-cehQbwtXKow            Chatime  333 Huntington Ave  Boston
# 14106  W_YBG1lPLB-cehQbwtXKow            Chatime  333 Huntington Ave  Boston
# 14107  W_YBG1lPLB-cehQbwtXKow            Chatime  333 Huntington Ave  Boston
#
# ...

# %%
x = "Horrible experience, ordered my drinks when there's not busy, being told that its gonna take 15 mins for drinks, there is a kungfu tea across street if I don't want to wait! Wtf ! Will never go back again!"

# %%
# !pip install torch
# Out:
# Looking in indexes: https://dev-team-local:****@klaviyo.jfrog.io/klaviyo/api/pypi/pypi/simple
# ...
#      |████████████████████████████████| 147.1 MB 21.1 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 20.2.3; however, version 21.3.1 is available.
# You should consider upgrading via the '/Users/justin.xu/.pyenv/versions/3.8.9/envs/restaurant/bin/python3.8 -m pip install --upgrade pip' command.

# %%
import torch
from transformers import AutoTokenizer, AutoModelWithLMHead

# %%
from textblob import TextBlob
TextBlob(x).sentiment
# Out:
# Sentiment(polarity=-0.421875, subjectivity=0.575)

# %%
for x in boston_boba[:10000].iterrows():
    if x[1].stars < 3:
        print(x[1]['name'])
        print(x[1].stars)
        print(x[1].text)
        print()
# Out:
# Chatime
# 2.0
# There was only one flavor of bubble tea at that time so I guess I would get it sooner than I thought. The truth is the people who ordered after me got their drinks first, and one of them ordered the same drink. The cashier, who was in charge, I assumed, didn't feel sorry when I complained, and joked with the staffs who were making the tea in Mandarin. So I talked to her again in Mandarin, repeating what I said earlier in English, and she provoked me by telling her colleagues to ease and take their time to make my bubble tea.
# The drink is ok. I could taste some taro in the milk tea so I could tell it wasn't just some flavored powder in it. But the service is the WORST.
#
# Chatime
# 2.0
# Extremely slow and don't know the difference between Taro and Thai iced tea. Staff seemed to not care at all.
#
# Chatime
# 2.0
# ...
